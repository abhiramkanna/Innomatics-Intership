# %%
#Logic building task-1(python basics task)
#1.User Login check
#code:
#defining username and password
given_username="admin"
given_password="1234"
#input from user
username=input("Enter username")
password=input("Enter password")
#Condition
if username == given_username and password == given_password:
    print("Login Successful")
else:
    print("Invalid Credentials")
# Out:
# Enter username admin
# Enter password 1234
# Login Successful

# %%
#2.Pass/Fail Analyzer
#code:
marks=[45, 78, 90, 33, 60]
pass_count=0
fail_count=0
for mark in marks:
    if mark >=50:
        pass_count=pass_count+1
    else:
        fail_count=fail_count+1
        
print("Total Students:", len(marks))
print("Pass Students:", pass_count)
print("Fail Students:", fail_count)
# Out:
# Total Students: 5
# Pass Students: 3
# Fail Students: 2

# %%
#3.Simple data cleaner
#code:
names = [" Alice ", "bob", " CHARLIE "]
Cleaned_names=[]
for name in names:
    #remove extra space
    name=name.strip()
    #convert to lowercase
    name=name.lower()
    Cleaned_names.append(name)
print("cleaned names:",Cleaned_names)
# Out:
# cleaned names: ['alice', 'bob', 'charlie']

# %%
#4.Message lenth analyzer
#code:
messages = ["Hi", "Welcome to the platform", "OK"]
for message in messages:
    length = len(message)
    print("Message:", message and "Lengths:",length)
    if length > 10:
        print("→ Flag: Message longer than 10 characters\n")
    else:
        print("→ Status: Message length is acceptable\n")
# Out:
# Message: Lengths: 2
# → Status: Message length is acceptable
#
# Message: Lengths: 23
# → Flag: Message longer than 10 characters
#
# Message: Lengths: 2
# → Status: Message length is acceptable

# %%
#5.Error message detector
#code:
logs = ["INFO", "ERROR", "WARNING", "ERROR"]
#condition/logic
error_count = logs.count("ERROR")

print("Total ERROR messages:", error_count)
# Out:
# Total ERROR messages: 2
